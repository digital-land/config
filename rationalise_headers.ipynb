# %%
import pandas as pd
import os
import json

# %%
# read in schema field df, and create list of valid file names
schema_field_df = pd.read_csv("specification/schema-field.csv")
valid_file_names = schema_field_df["schema"].drop_duplicates().to_list()

# %%
# inputs
dir_name = input("Enter the name of the directory to check: ")
save_results = input("Would you like to save lists of all files with extra or missing fields? (y/n): ")
remove_changes = input("Would you like to remove extra fields? (y/n)")
remove_only_empty = input("When removing fields would you like to remove only those with no values? (y/n)")
add_changes = input("Would you like to add in missing fields? (y/n)")

# %%
# functions
def get_schema_fields(file_name):
    
    schema_fields = schema_field_df[schema_field_df["schema"] == file_name]["field"].to_list()
    return schema_fields

def check_for_extra_fields(df, file_name):

    # filter schema fields csv to file name and create list
    schema_fields = get_schema_fields(file_name)
    df_fields = df.columns.to_list()

    if len(schema_fields) == 0:
        print(f"Error: schema for '{file_name}' not found in schema-field.csv")
        raise ValueError(f"Error: schema not found in schema-field.csv")

    # find df fields not in schema list
    extra_fields = list(set(df_fields).difference(schema_fields))

    results = []
    # save a dict of field name and n non-null values
    for field in extra_fields:

        results.append(dict({
            "field_name" : field,
            "n_values" : len(df[df[field].notnull()])
        }))

    return results


def check_for_missing_fields(df, file_name):

    # filter schema fields csv to file name and create list
    schema_fields = schema_field_df[schema_field_df["schema"] == file_name]["field"].to_list()
    df_fields = df.columns.to_list()

    if len(schema_fields) == 0:
        print(f"Error: schema for '{file_name}' not found in schema-field.csv")
        raise ValueError(f"Error: schema not found in schema-field.csv")

    # find df fields not in schema list
    missing_fields = list(set(schema_fields).difference(df_fields))

    return missing_fields
    
# test = pd.read_csv("pipeline_test/ancient-woodland/column.csv")
# check_for_extra_fields(test, "column")

# %%
# check for any files with extra fields

results_extra_fields = []

for path,subdir,files in os.walk(dir_name):
   for file in files:    
       
       collection_name = path.split("/")[-1]
       file_name = file.split(".")[0]

       if file.lower().endswith('.csv') & any(file_name.lower() in fn for fn in valid_file_names):
          
          try:
             df = pd.read_csv(os.path.join(path, file), dtype = str)
             
             extra_fields = check_for_extra_fields(df, file_name)

             if len(extra_fields) > 0:

               results_extra_fields.append(dict({
                  "file_path" : os.path.join(path, file),
                  "extra_fields" : extra_fields
               }))

          except pd.errors.EmptyDataError:
             print(f"Empty CSV file: {file}")
          except pd.errors.ParserError:
             print(f"Error reading CSV file: {file}")


if save_results.lower() == "y":
   with open(dir_name + "-files_extra_fields.json", "w") as f:
      json.dump(results_extra_fields, f , indent = 2)

# %%
# remove all extra fields (or EMPTY fields only depending on remove_only_empty)

if remove_changes.lower() == "y":
    for file in results_extra_fields:
        print("Reading file: " + file["file_path"])
        df = pd.read_csv(file["file_path"], dtype = str)

        for field in file["extra_fields"]:

            if remove_only_empty.lower() == "y":
                if field["n_values"] == 0:
                    df.drop(field["field_name"], axis = 1, inplace = True)
                    print("Dropped field: " + field["field_name"])

            else:
                df.drop(field["field_name"], axis = 1, inplace = True)
                print("Dropped field: " + field["field_name"])
        
        df.to_csv(file["file_path"], index = False)
        # print("Overwritten file: " + file["file_path"])
        print("-" * 50)
# Out:
# Reading file: pipeline/local-nature-reserve/convert.csv
# Dropped field: script
# --------------------------------------------------
# Reading file: pipeline/local-nature-reserve/transform.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/design-code/convert.csv
# Dropped field: script
# --------------------------------------------------
# Reading file: pipeline/local-authority-district/convert.csv
# Dropped field: script
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/local-authority-district/patch.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/local-authority-district/concat.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/local-authority-district/transform.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/local-authority-district/skip.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/national-nature-reserve/convert.csv
# Dropped field: script
# --------------------------------------------------
# Reading file: pipeline/national-nature-reserve/transform.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/listed-building/convert.csv
# Dropped field: script
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/listed-building/concat.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/listed-building/transform.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/listed-building/skip.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/ramsar/convert.csv
# Dropped field: script
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/ramsar/patch.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/ramsar/concat.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/ramsar/transform.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/ramsar/skip.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/tree-preservation-order/convert.csv
# Dropped field: script
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/tree-preservation-order/patch.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/tree-preservation-order/filter.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/tree-preservation-order/transform.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/tree-preservation-order/skip.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/local-resilience-forum-boundary/convert.csv
# Dropped field: script
# --------------------------------------------------
# Reading file: pipeline/area-of-outstanding-natural-beauty/convert.csv
# Dropped field: script
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/area-of-outstanding-natural-beauty/concat.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/area-of-outstanding-natural-beauty/transform.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/area-of-outstanding-natural-beauty/skip.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/brownfield-site/convert.csv
# Dropped field: script
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/brownfield-site/patch.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/brownfield-site/concat.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/brownfield-site/transform.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/brownfield-site/skip.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/flood-risk-zone/convert.csv
# Dropped field: script
# --------------------------------------------------
# Reading file: pipeline/flood-risk-zone/transform.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/historic-england/convert.csv
# Dropped field: script
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/historic-england/patch.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/historic-england/transform.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/historic-england/skip.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/document/convert.csv
# Dropped field: script
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/document/patch.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/document/concat.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/document/transform.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/document/skip.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/site-of-special-scientific-interest/convert.csv
# Dropped field: script
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/site-of-special-scientific-interest/patch.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/site-of-special-scientific-interest/concat.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/site-of-special-scientific-interest/transform.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/site-of-special-scientific-interest/skip.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/parish/convert.csv
# Dropped field: script
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/parish/patch.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/parish/concat.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/parish/transform.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/parish/skip.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/special-protection-area/convert.csv
# Dropped field: script
# --------------------------------------------------
# Reading file: pipeline/region/convert.csv
# Dropped field: script
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/region/patch.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/region/filter.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/region/concat.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/region/transform.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/region/skip.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/ownership-status/convert.csv
# Dropped field: script
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/ownership-status/patch.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/ownership-status/concat.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/ownership-status/transform.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/ownership-status/skip.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/infrastructure-project/convert.csv
# Dropped field: script
# --------------------------------------------------
# Reading file: pipeline/ancient-woodland/convert.csv
# Dropped field: script
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/ancient-woodland/patch.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/ancient-woodland/concat.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/ancient-woodland/transform.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/ancient-woodland/skip.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/planning-permission-type/convert.csv
# Dropped field: script
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/planning-permission-type/patch.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/planning-permission-type/concat.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/planning-permission-type/transform.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/planning-permission-type/skip.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/infrastructure-funding-statement/column.csv
# Dropped field: pattern
# Dropped field: value
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/infrastructure-funding-statement/convert.csv
# Dropped field: script
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/infrastructure-funding-statement/patch.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/infrastructure-funding-statement/concat.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/infrastructure-funding-statement/transform.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/infrastructure-funding-statement/skip.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/organisation/convert.csv
# Dropped field: script
# --------------------------------------------------
# Reading file: pipeline/article-4-direction/convert.csv
# Dropped field: script
# --------------------------------------------------
# Reading file: pipeline/special-area-of-conservation/convert.csv
# Dropped field: script
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/special-area-of-conservation/patch.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/special-area-of-conservation/concat.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/special-area-of-conservation/transform.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/special-area-of-conservation/skip.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/heritage-coast/convert.csv
# Dropped field: script
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/heritage-coast/patch.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/heritage-coast/concat.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/heritage-coast/transform.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/heritage-coast/skip.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/title-boundary/convert.csv
# Dropped field: script
# --------------------------------------------------
# Reading file: pipeline/title-boundary/transform.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/green-belt/convert.csv
# Dropped field: script
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/green-belt/filter.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/green-belt/concat.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/green-belt/transform.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/green-belt/skip.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/legislation/convert.csv
# Dropped field: script
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/legislation/patch.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/legislation/filter.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/legislation/concat.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/legislation/transform.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/legislation/skip.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/local-planning-authority/convert.csv
# Dropped field: script
# --------------------------------------------------
# Reading file: pipeline/brownfield-land/convert.csv
# Dropped field: script
# --------------------------------------------------
# Reading file: pipeline/conservation-area/convert.csv
# Dropped field: script
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/conservation-area/skip.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/planning-permission-status/convert.csv
# Dropped field: script
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/planning-permission-status/patch.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/planning-permission-status/concat.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/planning-permission-status/transform.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/planning-permission-status/skip.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/developer-contributions/convert.csv
# Dropped field: script
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/developer-contributions/concat.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/developer-contributions/transform.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/national-park/convert.csv
# Dropped field: script
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/national-park/patch.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/national-park/concat.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/national-park/transform.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/national-park/skip.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/site-category/convert.csv
# Dropped field: script
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/site-category/patch.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/site-category/concat.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/site-category/transform.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/site-category/skip.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/central-activities-zone/convert.csv
# Dropped field: script
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/central-activities-zone/patch.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/central-activities-zone/filter.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/central-activities-zone/concat.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/central-activities-zone/transform.csv
# Dropped field: pipeline
# --------------------------------------------------
# Reading file: pipeline/central-activities-zone/skip.csv
# Dropped field: pipeline
# --------------------------------------------------

# %%
# check for any files with extra fields

results_missing_fields = []

for path,subdir,files in os.walk(dir_name):
   for file in files:    
       
       collection_name = path.split("/")[-1]
       file_name = file.split(".")[0]

       if file.lower().endswith('.csv') & any(file_name.lower() in fn for fn in valid_file_names):
          
          try:
             df = pd.read_csv(os.path.join(path, file), dtype = str)
             
             missing_fields = check_for_missing_fields(df, file_name)

             if len(missing_fields) > 0:

               results_missing_fields.append(dict({
                  "file_path" : os.path.join(path, file),
                  "missing_fields" : missing_fields
               }))

          except pd.errors.EmptyDataError:
             print(f"Empty CSV file: {file}")
          except pd.errors.ParserError:
             print(f"Error reading CSV file: {file}")

# pd.DataFrame.from_dict(results_extra_fields).to_csv(dir_name + "-consistency_check_results.csv", index = False)

if save_results.lower() == "y":
   with open(dir_name + "-files_missing_fields.json", "w") as f:
      json.dump(results_missing_fields, f , indent = 2)

# %%
# add in all missing fields

if add_changes.lower() == "y":
    for file in results_missing_fields:
        print("Reading file: " + file["file_path"])
        df = pd.read_csv(file["file_path"], dtype = str)
        
        # add empty fields for all missing
        df[file["missing_fields"]] = None
        print("Added fields: " + ", ".join(file["missing_fields"]))

        df.to_csv(file["file_path"], index = False)
        print("Overwritten file: " + file["file_path"])
        print("-" * 50)
# Out:
# Reading file: pipeline/local-nature-reserve/default-value.csv
# Added fields: entry-number, resource, start-date, end-date, entry-date
# Overwritten file: pipeline/local-nature-reserve/default-value.csv
# --------------------------------------------------
# Reading file: pipeline/local-nature-reserve/combine.csv
# Added fields: resource
# Overwritten file: pipeline/local-nature-reserve/combine.csv
# --------------------------------------------------
# Reading file: pipeline/local-nature-reserve/column.csv
# Added fields: start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/local-nature-reserve/column.csv
# --------------------------------------------------
# Reading file: pipeline/local-nature-reserve/convert.csv
# Added fields: plugin, start-date, end-date, entry-date, endpoint, parameters
# Overwritten file: pipeline/local-nature-reserve/convert.csv
# --------------------------------------------------
# Reading file: pipeline/local-nature-reserve/default.csv
# Added fields: entry-number, endpoint
# Overwritten file: pipeline/local-nature-reserve/default.csv
# --------------------------------------------------
# Reading file: pipeline/local-nature-reserve/patch.csv
# Added fields: entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/local-nature-reserve/patch.csv
# --------------------------------------------------
# Reading file: pipeline/local-nature-reserve/concat.csv
# Added fields: endpoint
# Overwritten file: pipeline/local-nature-reserve/concat.csv
# --------------------------------------------------
# Reading file: pipeline/local-nature-reserve/transform.csv
# Added fields: dataset, entry-number, resource, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/local-nature-reserve/transform.csv
# --------------------------------------------------
# Reading file: pipeline/local-nature-reserve/skip.csv
# Added fields: entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/local-nature-reserve/skip.csv
# --------------------------------------------------
# Reading file: pipeline/local-nature-reserve/lookup.csv
# Added fields: value, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/local-nature-reserve/lookup.csv
# --------------------------------------------------
# Reading file: pipeline/local-nature-reserve/old-entity.csv
# Added fields: end-date, entry-date, start-date
# Overwritten file: pipeline/local-nature-reserve/old-entity.csv
# --------------------------------------------------
# Reading file: pipeline/design-code/default-value.csv
# Added fields: entry-number, resource, start-date, end-date, entry-date
# Overwritten file: pipeline/design-code/default-value.csv
# --------------------------------------------------
# Reading file: pipeline/design-code/column.csv
# Added fields: start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/design-code/column.csv
# --------------------------------------------------
# Reading file: pipeline/design-code/convert.csv
# Added fields: plugin, start-date, end-date, entry-date, endpoint, parameters
# Overwritten file: pipeline/design-code/convert.csv
# --------------------------------------------------
# Reading file: pipeline/design-code/default.csv
# Added fields: entry-number, endpoint
# Overwritten file: pipeline/design-code/default.csv
# --------------------------------------------------
# Reading file: pipeline/design-code/patch.csv
# Added fields: entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/design-code/patch.csv
# --------------------------------------------------
# Reading file: pipeline/design-code/concat.csv
# Added fields: endpoint
# Overwritten file: pipeline/design-code/concat.csv
# --------------------------------------------------
# Reading file: pipeline/design-code/skip.csv
# Added fields: entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/design-code/skip.csv
# --------------------------------------------------
# Reading file: pipeline/design-code/lookup.csv
# Added fields: value, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/design-code/lookup.csv
# --------------------------------------------------
# Reading file: pipeline/design-code/old-entity.csv
# Added fields: end-date, entry-date, start-date
# Overwritten file: pipeline/design-code/old-entity.csv
# --------------------------------------------------
# Reading file: pipeline/infrastructure-funding-statement-collection/old-entity.csv
# Added fields: end-date, entry-date, start-date
# Overwritten file: pipeline/infrastructure-funding-statement-collection/old-entity.csv
# --------------------------------------------------
# Reading file: pipeline/local-authority-district/column.csv
# Added fields: start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/local-authority-district/column.csv
# --------------------------------------------------
# Reading file: pipeline/local-authority-district/convert.csv
# Added fields: dataset, plugin, start-date, end-date, entry-date, endpoint, parameters
# Overwritten file: pipeline/local-authority-district/convert.csv
# --------------------------------------------------
# Reading file: pipeline/local-authority-district/default.csv
# Added fields: entry-number, endpoint
# Overwritten file: pipeline/local-authority-district/default.csv
# --------------------------------------------------
# Reading file: pipeline/local-authority-district/patch.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/local-authority-district/patch.csv
# --------------------------------------------------
# Reading file: pipeline/local-authority-district/filter.csv
# Added fields: entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/local-authority-district/filter.csv
# --------------------------------------------------
# Reading file: pipeline/local-authority-district/concat.csv
# Added fields: dataset, endpoint
# Overwritten file: pipeline/local-authority-district/concat.csv
# --------------------------------------------------
# Reading file: pipeline/local-authority-district/transform.csv
# Added fields: dataset, entry-number, resource, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/local-authority-district/transform.csv
# --------------------------------------------------
# Reading file: pipeline/local-authority-district/skip.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/local-authority-district/skip.csv
# --------------------------------------------------
# Reading file: pipeline/local-authority-district/lookup.csv
# Added fields: value, entry-number, resource, start-date, organisation, end-date, entry-date, endpoint
# Overwritten file: pipeline/local-authority-district/lookup.csv
# --------------------------------------------------
# Reading file: pipeline/local-authority-district/old-entity.csv
# Added fields: end-date, entry-date, start-date
# Overwritten file: pipeline/local-authority-district/old-entity.csv
# --------------------------------------------------
# Reading file: pipeline/national-nature-reserve/default-value.csv
# Added fields: entry-number, resource, start-date, end-date, entry-date
# Overwritten file: pipeline/national-nature-reserve/default-value.csv
# --------------------------------------------------
# Reading file: pipeline/national-nature-reserve/combine.csv
# Added fields: resource
# Overwritten file: pipeline/national-nature-reserve/combine.csv
# --------------------------------------------------
# Reading file: pipeline/national-nature-reserve/column.csv
# Added fields: start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/national-nature-reserve/column.csv
# --------------------------------------------------
# Reading file: pipeline/national-nature-reserve/convert.csv
# Added fields: plugin, start-date, end-date, entry-date, endpoint, parameters
# Overwritten file: pipeline/national-nature-reserve/convert.csv
# --------------------------------------------------
# Reading file: pipeline/national-nature-reserve/default.csv
# Added fields: entry-number, endpoint
# Overwritten file: pipeline/national-nature-reserve/default.csv
# --------------------------------------------------
# Reading file: pipeline/national-nature-reserve/patch.csv
# Added fields: entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/national-nature-reserve/patch.csv
# --------------------------------------------------
# Reading file: pipeline/national-nature-reserve/concat.csv
# Added fields: endpoint
# Overwritten file: pipeline/national-nature-reserve/concat.csv
# --------------------------------------------------
# Reading file: pipeline/national-nature-reserve/transform.csv
# Added fields: dataset, entry-number, resource, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/national-nature-reserve/transform.csv
# --------------------------------------------------
# Reading file: pipeline/national-nature-reserve/skip.csv
# Added fields: entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/national-nature-reserve/skip.csv
# --------------------------------------------------
# Reading file: pipeline/national-nature-reserve/lookup.csv
# Added fields: value, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/national-nature-reserve/lookup.csv
# --------------------------------------------------
# Reading file: pipeline/national-nature-reserve/old-entity.csv
# Added fields: end-date, entry-date, start-date
# Overwritten file: pipeline/national-nature-reserve/old-entity.csv
# --------------------------------------------------
# Reading file: pipeline/listed-building/combine.csv
# Added fields: resource
# Overwritten file: pipeline/listed-building/combine.csv
# --------------------------------------------------
# Reading file: pipeline/listed-building/column.csv
# Added fields: start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/listed-building/column.csv
# --------------------------------------------------
# Reading file: pipeline/listed-building/convert.csv
# Added fields: dataset, plugin, start-date, end-date, entry-date, endpoint, parameters
# Overwritten file: pipeline/listed-building/convert.csv
# --------------------------------------------------
# Reading file: pipeline/listed-building/default.csv
# Added fields: entry-number, endpoint
# Overwritten file: pipeline/listed-building/default.csv
# --------------------------------------------------
# Reading file: pipeline/listed-building/patch.csv
# Added fields: entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/listed-building/patch.csv
# --------------------------------------------------
# Reading file: pipeline/listed-building/concat.csv
# Added fields: dataset, endpoint
# Overwritten file: pipeline/listed-building/concat.csv
# --------------------------------------------------
# Reading file: pipeline/listed-building/transform.csv
# Added fields: dataset, entry-number, resource, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/listed-building/transform.csv
# --------------------------------------------------
# Reading file: pipeline/listed-building/skip.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/listed-building/skip.csv
# --------------------------------------------------
# Reading file: pipeline/listed-building/lookup.csv
# Added fields: value, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/listed-building/lookup.csv
# --------------------------------------------------
# Reading file: pipeline/listed-building/old-entity.csv
# Added fields: end-date, entry-date, start-date
# Overwritten file: pipeline/listed-building/old-entity.csv
# --------------------------------------------------
# Reading file: pipeline/ramsar/combine.csv
# Added fields: resource
# Overwritten file: pipeline/ramsar/combine.csv
# --------------------------------------------------
# Reading file: pipeline/ramsar/column.csv
# Added fields: start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/ramsar/column.csv
# --------------------------------------------------
# Reading file: pipeline/ramsar/convert.csv
# Added fields: dataset, plugin, start-date, end-date, entry-date, endpoint, parameters
# Overwritten file: pipeline/ramsar/convert.csv
# --------------------------------------------------
# Reading file: pipeline/ramsar/default.csv
# Added fields: entry-number, endpoint
# Overwritten file: pipeline/ramsar/default.csv
# --------------------------------------------------
# Reading file: pipeline/ramsar/patch.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/ramsar/patch.csv
# --------------------------------------------------
# Reading file: pipeline/ramsar/concat.csv
# Added fields: dataset, endpoint
# Overwritten file: pipeline/ramsar/concat.csv
# --------------------------------------------------
# Reading file: pipeline/ramsar/transform.csv
# Added fields: dataset, entry-number, resource, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/ramsar/transform.csv
# --------------------------------------------------
# Reading file: pipeline/ramsar/skip.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/ramsar/skip.csv
# --------------------------------------------------
# Reading file: pipeline/ramsar/lookup.csv
# Added fields: value, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/ramsar/lookup.csv
# --------------------------------------------------
# Reading file: pipeline/ramsar/old-entity.csv
# Added fields: end-date, entry-date, start-date
# Overwritten file: pipeline/ramsar/old-entity.csv
# --------------------------------------------------
# Reading file: pipeline/tree-preservation-order/default-value.csv
# Added fields: start-date, end-date, entry-date
# Overwritten file: pipeline/tree-preservation-order/default-value.csv
# --------------------------------------------------
# Reading file: pipeline/tree-preservation-order/combine.csv
# Added fields: resource
# Overwritten file: pipeline/tree-preservation-order/combine.csv
# --------------------------------------------------
# Reading file: pipeline/tree-preservation-order/column.csv
# Added fields: start-date, end-date, entry-date
# Overwritten file: pipeline/tree-preservation-order/column.csv
# --------------------------------------------------
# Reading file: pipeline/tree-preservation-order/convert.csv
# Added fields: dataset, plugin, start-date, end-date, entry-date, endpoint, parameters
# Overwritten file: pipeline/tree-preservation-order/convert.csv
# --------------------------------------------------
# Reading file: pipeline/tree-preservation-order/default.csv
# Added fields: entry-number, endpoint
# Overwritten file: pipeline/tree-preservation-order/default.csv
# --------------------------------------------------
# Reading file: pipeline/tree-preservation-order/patch.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/tree-preservation-order/patch.csv
# --------------------------------------------------
# Reading file: pipeline/tree-preservation-order/filter.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/tree-preservation-order/filter.csv
# --------------------------------------------------
# Reading file: pipeline/tree-preservation-order/transform.csv
# Added fields: dataset, entry-number, resource, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/tree-preservation-order/transform.csv
# --------------------------------------------------
# Reading file: pipeline/tree-preservation-order/skip.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/tree-preservation-order/skip.csv
# --------------------------------------------------
# Reading file: pipeline/tree-preservation-order/lookup.csv
# Added fields: value, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/tree-preservation-order/lookup.csv
# --------------------------------------------------
# Reading file: pipeline/tree-preservation-order/old-entity.csv
# Added fields: end-date, entry-date, start-date
# Overwritten file: pipeline/tree-preservation-order/old-entity.csv
# --------------------------------------------------
# Reading file: pipeline/local-resilience-forum-boundary/default-value.csv
# Added fields: entry-number, resource, start-date, end-date, entry-date
# Overwritten file: pipeline/local-resilience-forum-boundary/default-value.csv
# --------------------------------------------------
# Reading file: pipeline/local-resilience-forum-boundary/combine.csv
# Added fields: resource
# Overwritten file: pipeline/local-resilience-forum-boundary/combine.csv
# --------------------------------------------------
# Reading file: pipeline/local-resilience-forum-boundary/column.csv
# Added fields: start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/local-resilience-forum-boundary/column.csv
# --------------------------------------------------
# Reading file: pipeline/local-resilience-forum-boundary/convert.csv
# Added fields: plugin, start-date, end-date, entry-date, endpoint, parameters
# Overwritten file: pipeline/local-resilience-forum-boundary/convert.csv
# --------------------------------------------------
# Reading file: pipeline/local-resilience-forum-boundary/default.csv
# Added fields: entry-number, endpoint
# Overwritten file: pipeline/local-resilience-forum-boundary/default.csv
# --------------------------------------------------
# Reading file: pipeline/local-resilience-forum-boundary/patch.csv
# Added fields: entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/local-resilience-forum-boundary/patch.csv
# --------------------------------------------------
# Reading file: pipeline/local-resilience-forum-boundary/filter.csv
# Added fields: entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/local-resilience-forum-boundary/filter.csv
# --------------------------------------------------
# Reading file: pipeline/local-resilience-forum-boundary/concat.csv
# Added fields: endpoint
# Overwritten file: pipeline/local-resilience-forum-boundary/concat.csv
# --------------------------------------------------
# Reading file: pipeline/local-resilience-forum-boundary/transform.csv
# Added fields: entry-number, resource, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/local-resilience-forum-boundary/transform.csv
# --------------------------------------------------
# Reading file: pipeline/local-resilience-forum-boundary/skip.csv
# Added fields: entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/local-resilience-forum-boundary/skip.csv
# --------------------------------------------------
# Reading file: pipeline/local-resilience-forum-boundary/lookup.csv
# Added fields: value, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/local-resilience-forum-boundary/lookup.csv
# --------------------------------------------------
# Reading file: pipeline/local-resilience-forum-boundary/old-entity.csv
# Added fields: end-date, entry-date, start-date
# Overwritten file: pipeline/local-resilience-forum-boundary/old-entity.csv
# --------------------------------------------------
# Reading file: pipeline/area-of-outstanding-natural-beauty/column.csv
# Added fields: start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/area-of-outstanding-natural-beauty/column.csv
# --------------------------------------------------
# Reading file: pipeline/area-of-outstanding-natural-beauty/convert.csv
# Added fields: dataset, plugin, start-date, end-date, entry-date, endpoint, parameters
# Overwritten file: pipeline/area-of-outstanding-natural-beauty/convert.csv
# --------------------------------------------------
# Reading file: pipeline/area-of-outstanding-natural-beauty/default.csv
# Added fields: entry-number, endpoint
# Overwritten file: pipeline/area-of-outstanding-natural-beauty/default.csv
# --------------------------------------------------
# Reading file: pipeline/area-of-outstanding-natural-beauty/patch.csv
# Added fields: entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/area-of-outstanding-natural-beauty/patch.csv
# --------------------------------------------------
# Reading file: pipeline/area-of-outstanding-natural-beauty/concat.csv
# Added fields: dataset, endpoint
# Overwritten file: pipeline/area-of-outstanding-natural-beauty/concat.csv
# --------------------------------------------------
# Reading file: pipeline/area-of-outstanding-natural-beauty/transform.csv
# Added fields: dataset, entry-number, resource, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/area-of-outstanding-natural-beauty/transform.csv
# --------------------------------------------------
# Reading file: pipeline/area-of-outstanding-natural-beauty/skip.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/area-of-outstanding-natural-beauty/skip.csv
# --------------------------------------------------
# Reading file: pipeline/area-of-outstanding-natural-beauty/lookup.csv
# Added fields: value, entry-number, resource, start-date, organisation, end-date, entry-date, endpoint
# Overwritten file: pipeline/area-of-outstanding-natural-beauty/lookup.csv
# --------------------------------------------------
# Reading file: pipeline/area-of-outstanding-natural-beauty/old-entity.csv
# Added fields: end-date, entry-date, start-date
# Overwritten file: pipeline/area-of-outstanding-natural-beauty/old-entity.csv
# --------------------------------------------------
# Reading file: pipeline/brownfield-site/column.csv
# Added fields: start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/brownfield-site/column.csv
# --------------------------------------------------
# Reading file: pipeline/brownfield-site/convert.csv
# Added fields: dataset, plugin, start-date, end-date, entry-date, endpoint, parameters
# Overwritten file: pipeline/brownfield-site/convert.csv
# --------------------------------------------------
# Reading file: pipeline/brownfield-site/default.csv
# Added fields: entry-number, endpoint
# Overwritten file: pipeline/brownfield-site/default.csv
# --------------------------------------------------
# Reading file: pipeline/brownfield-site/patch.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/brownfield-site/patch.csv
# --------------------------------------------------
# Reading file: pipeline/brownfield-site/concat.csv
# Added fields: dataset, endpoint
# Overwritten file: pipeline/brownfield-site/concat.csv
# --------------------------------------------------
# Reading file: pipeline/brownfield-site/transform.csv
# Added fields: dataset, entry-number, resource, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/brownfield-site/transform.csv
# --------------------------------------------------
# Reading file: pipeline/brownfield-site/skip.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/brownfield-site/skip.csv
# --------------------------------------------------
# Reading file: pipeline/brownfield-site/lookup.csv
# Added fields: value, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/brownfield-site/lookup.csv
# --------------------------------------------------
# Reading file: pipeline/brownfield-site/old-entity.csv
# Added fields: end-date, entry-date, start-date
# Overwritten file: pipeline/brownfield-site/old-entity.csv
# --------------------------------------------------
# Reading file: pipeline/flood-risk-zone/default-value.csv
# Added fields: entry-number, resource, start-date, end-date, entry-date
# Overwritten file: pipeline/flood-risk-zone/default-value.csv
# --------------------------------------------------
# Reading file: pipeline/flood-risk-zone/combine.csv
# Added fields: resource
# Overwritten file: pipeline/flood-risk-zone/combine.csv
# --------------------------------------------------
# Reading file: pipeline/flood-risk-zone/column.csv
# Added fields: start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/flood-risk-zone/column.csv
# --------------------------------------------------
# Reading file: pipeline/flood-risk-zone/convert.csv
# Added fields: plugin, start-date, end-date, entry-date, endpoint, parameters
# Overwritten file: pipeline/flood-risk-zone/convert.csv
# --------------------------------------------------
# Reading file: pipeline/flood-risk-zone/default.csv
# Added fields: entry-number, endpoint
# Overwritten file: pipeline/flood-risk-zone/default.csv
# --------------------------------------------------
# Reading file: pipeline/flood-risk-zone/patch.csv
# Added fields: entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/flood-risk-zone/patch.csv
# --------------------------------------------------
# Reading file: pipeline/flood-risk-zone/concat.csv
# Added fields: endpoint
# Overwritten file: pipeline/flood-risk-zone/concat.csv
# --------------------------------------------------
# Reading file: pipeline/flood-risk-zone/transform.csv
# Added fields: dataset, entry-number, resource, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/flood-risk-zone/transform.csv
# --------------------------------------------------
# Reading file: pipeline/flood-risk-zone/skip.csv
# Added fields: entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/flood-risk-zone/skip.csv
# --------------------------------------------------
# Reading file: pipeline/flood-risk-zone/lookup.csv
# Added fields: value, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/flood-risk-zone/lookup.csv
# --------------------------------------------------
# Reading file: pipeline/flood-risk-zone/old-entity.csv
# Added fields: end-date, entry-date, start-date
# Overwritten file: pipeline/flood-risk-zone/old-entity.csv
# --------------------------------------------------
# Reading file: pipeline/historic-england/column.csv
# Added fields: start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/historic-england/column.csv
# --------------------------------------------------
# Reading file: pipeline/historic-england/convert.csv
# Added fields: dataset, plugin, start-date, end-date, entry-date, endpoint, parameters
# Overwritten file: pipeline/historic-england/convert.csv
# --------------------------------------------------
# Reading file: pipeline/historic-england/default.csv
# Added fields: entry-number, endpoint
# Overwritten file: pipeline/historic-england/default.csv
# --------------------------------------------------
# Reading file: pipeline/historic-england/patch.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/historic-england/patch.csv
# --------------------------------------------------
# Reading file: pipeline/historic-england/filter.csv
# Added fields: entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/historic-england/filter.csv
# --------------------------------------------------
# Reading file: pipeline/historic-england/concat.csv
# Added fields: endpoint
# Overwritten file: pipeline/historic-england/concat.csv
# --------------------------------------------------
# Reading file: pipeline/historic-england/transform.csv
# Added fields: dataset, entry-number, resource, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/historic-england/transform.csv
# --------------------------------------------------
# Reading file: pipeline/historic-england/skip.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/historic-england/skip.csv
# --------------------------------------------------
# Reading file: pipeline/historic-england/lookup.csv
# Added fields: value, entry-number, resource, start-date, organisation, end-date, entry-date, endpoint
# Overwritten file: pipeline/historic-england/lookup.csv
# --------------------------------------------------
# Reading file: pipeline/historic-england/old-entity.csv
# Added fields: end-date, entry-date, start-date
# Overwritten file: pipeline/historic-england/old-entity.csv
# --------------------------------------------------
# Reading file: pipeline/document/column.csv
# Added fields: start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/document/column.csv
# --------------------------------------------------
# Reading file: pipeline/document/convert.csv
# Added fields: dataset, plugin, start-date, end-date, entry-date, endpoint, parameters
# Overwritten file: pipeline/document/convert.csv
# --------------------------------------------------
# Reading file: pipeline/document/default.csv
# Added fields: entry-number, endpoint
# Overwritten file: pipeline/document/default.csv
# --------------------------------------------------
# Reading file: pipeline/document/patch.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/document/patch.csv
# --------------------------------------------------
# Reading file: pipeline/document/concat.csv
# Added fields: dataset, endpoint
# Overwritten file: pipeline/document/concat.csv
# --------------------------------------------------
# Reading file: pipeline/document/transform.csv
# Added fields: dataset, entry-number, resource, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/document/transform.csv
# --------------------------------------------------
# Reading file: pipeline/document/skip.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/document/skip.csv
# --------------------------------------------------
# Reading file: pipeline/document/lookup.csv
# Added fields: value, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/document/lookup.csv
# --------------------------------------------------
# Reading file: pipeline/document/old-entity.csv
# Added fields: end-date, entry-date, start-date
# Overwritten file: pipeline/document/old-entity.csv
# --------------------------------------------------
# Reading file: pipeline/site-of-special-scientific-interest/combine.csv
# Added fields: resource
# Overwritten file: pipeline/site-of-special-scientific-interest/combine.csv
# --------------------------------------------------
# Reading file: pipeline/site-of-special-scientific-interest/column.csv
# Added fields: start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/site-of-special-scientific-interest/column.csv
# --------------------------------------------------
# Reading file: pipeline/site-of-special-scientific-interest/convert.csv
# Added fields: dataset, plugin, start-date, end-date, entry-date, endpoint, parameters
# Overwritten file: pipeline/site-of-special-scientific-interest/convert.csv
# --------------------------------------------------
# Reading file: pipeline/site-of-special-scientific-interest/default.csv
# Added fields: entry-number, endpoint
# Overwritten file: pipeline/site-of-special-scientific-interest/default.csv
# --------------------------------------------------
# Reading file: pipeline/site-of-special-scientific-interest/patch.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/site-of-special-scientific-interest/patch.csv
# --------------------------------------------------
# Reading file: pipeline/site-of-special-scientific-interest/concat.csv
# Added fields: dataset, endpoint
# Overwritten file: pipeline/site-of-special-scientific-interest/concat.csv
# --------------------------------------------------
# Reading file: pipeline/site-of-special-scientific-interest/transform.csv
# Added fields: dataset, entry-number, resource, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/site-of-special-scientific-interest/transform.csv
# --------------------------------------------------
# Reading file: pipeline/site-of-special-scientific-interest/skip.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/site-of-special-scientific-interest/skip.csv
# --------------------------------------------------
# Reading file: pipeline/site-of-special-scientific-interest/lookup.csv
# Added fields: value, entry-number, resource, start-date, organisation, end-date, entry-date, endpoint
# Overwritten file: pipeline/site-of-special-scientific-interest/lookup.csv
# --------------------------------------------------
# Reading file: pipeline/site-of-special-scientific-interest/old-entity.csv
# Added fields: end-date, entry-date, start-date
# Overwritten file: pipeline/site-of-special-scientific-interest/old-entity.csv
# --------------------------------------------------
# Reading file: pipeline/parish/column.csv
# Added fields: start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/parish/column.csv
# --------------------------------------------------
# Reading file: pipeline/parish/convert.csv
# Added fields: dataset, plugin, start-date, end-date, entry-date, endpoint, parameters
# Overwritten file: pipeline/parish/convert.csv
# --------------------------------------------------
# Reading file: pipeline/parish/default.csv
# Added fields: entry-number, endpoint
# Overwritten file: pipeline/parish/default.csv
# --------------------------------------------------
# Reading file: pipeline/parish/patch.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/parish/patch.csv
# --------------------------------------------------
# Reading file: pipeline/parish/filter.csv
# Added fields: entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/parish/filter.csv
# --------------------------------------------------
# Reading file: pipeline/parish/concat.csv
# Added fields: dataset, endpoint
# Overwritten file: pipeline/parish/concat.csv
# --------------------------------------------------
# Reading file: pipeline/parish/transform.csv
# Added fields: dataset, entry-number, resource, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/parish/transform.csv
# --------------------------------------------------
# Reading file: pipeline/parish/skip.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/parish/skip.csv
# --------------------------------------------------
# Reading file: pipeline/parish/lookup.csv
# Added fields: value, entry-number, resource, start-date, organisation, end-date, entry-date, endpoint
# Overwritten file: pipeline/parish/lookup.csv
# --------------------------------------------------
# Reading file: pipeline/parish/old-entity.csv
# Added fields: end-date, entry-date, start-date
# Overwritten file: pipeline/parish/old-entity.csv
# --------------------------------------------------
# Reading file: pipeline/special-protection-area/default-value.csv
# Added fields: entry-number, resource, start-date, end-date, entry-date
# Overwritten file: pipeline/special-protection-area/default-value.csv
# --------------------------------------------------
# Reading file: pipeline/special-protection-area/combine.csv
# Added fields: resource
# Overwritten file: pipeline/special-protection-area/combine.csv
# --------------------------------------------------
# Reading file: pipeline/special-protection-area/column.csv
# Added fields: start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/special-protection-area/column.csv
# --------------------------------------------------
# Reading file: pipeline/special-protection-area/convert.csv
# Added fields: plugin, start-date, end-date, entry-date, endpoint, parameters
# Overwritten file: pipeline/special-protection-area/convert.csv
# --------------------------------------------------
# Reading file: pipeline/special-protection-area/default.csv
# Added fields: entry-number, endpoint
# Overwritten file: pipeline/special-protection-area/default.csv
# --------------------------------------------------
# Reading file: pipeline/special-protection-area/patch.csv
# Added fields: entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/special-protection-area/patch.csv
# --------------------------------------------------
# Reading file: pipeline/special-protection-area/concat.csv
# Added fields: endpoint
# Overwritten file: pipeline/special-protection-area/concat.csv
# --------------------------------------------------
# Reading file: pipeline/special-protection-area/skip.csv
# Added fields: entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/special-protection-area/skip.csv
# --------------------------------------------------
# Reading file: pipeline/special-protection-area/lookup.csv
# Added fields: value, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/special-protection-area/lookup.csv
# --------------------------------------------------
# Reading file: pipeline/special-protection-area/old-entity.csv
# Added fields: end-date, entry-date, start-date
# Overwritten file: pipeline/special-protection-area/old-entity.csv
# --------------------------------------------------
# Reading file: pipeline/region/column.csv
# Added fields: start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/region/column.csv
# --------------------------------------------------
# Reading file: pipeline/region/convert.csv
# Added fields: dataset, plugin, start-date, end-date, entry-date, endpoint, parameters
# Overwritten file: pipeline/region/convert.csv
# --------------------------------------------------
# Reading file: pipeline/region/default.csv
# Added fields: entry-number, endpoint
# Overwritten file: pipeline/region/default.csv
# --------------------------------------------------
# Reading file: pipeline/region/patch.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/region/patch.csv
# --------------------------------------------------
# Reading file: pipeline/region/filter.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/region/filter.csv
# --------------------------------------------------
# Reading file: pipeline/region/concat.csv
# Added fields: dataset, endpoint
# Overwritten file: pipeline/region/concat.csv
# --------------------------------------------------
# Reading file: pipeline/region/transform.csv
# Added fields: dataset, entry-number, resource, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/region/transform.csv
# --------------------------------------------------
# Reading file: pipeline/region/skip.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/region/skip.csv
# --------------------------------------------------
# Reading file: pipeline/region/lookup.csv
# Added fields: value, entry-number, resource, start-date, organisation, end-date, entry-date, endpoint
# Overwritten file: pipeline/region/lookup.csv
# --------------------------------------------------
# Reading file: pipeline/region/old-entity.csv
# Added fields: end-date, entry-date, start-date
# Overwritten file: pipeline/region/old-entity.csv
# --------------------------------------------------
# Reading file: pipeline/ownership-status/column.csv
# Added fields: start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/ownership-status/column.csv
# --------------------------------------------------
# Reading file: pipeline/ownership-status/convert.csv
# Added fields: dataset, plugin, start-date, end-date, entry-date, endpoint, parameters
# Overwritten file: pipeline/ownership-status/convert.csv
# --------------------------------------------------
# Reading file: pipeline/ownership-status/default.csv
# Added fields: entry-number, endpoint
# Overwritten file: pipeline/ownership-status/default.csv
# --------------------------------------------------
# Reading file: pipeline/ownership-status/patch.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/ownership-status/patch.csv
# --------------------------------------------------
# Reading file: pipeline/ownership-status/concat.csv
# Added fields: dataset, endpoint
# Overwritten file: pipeline/ownership-status/concat.csv
# --------------------------------------------------
# Reading file: pipeline/ownership-status/transform.csv
# Added fields: dataset, entry-number, resource, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/ownership-status/transform.csv
# --------------------------------------------------
# Reading file: pipeline/ownership-status/skip.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/ownership-status/skip.csv
# --------------------------------------------------
# Reading file: pipeline/ownership-status/lookup.csv
# Added fields: value, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/ownership-status/lookup.csv
# --------------------------------------------------
# Reading file: pipeline/ownership-status/old-entity.csv
# Added fields: end-date, entry-date, start-date
# Overwritten file: pipeline/ownership-status/old-entity.csv
# --------------------------------------------------
# Reading file: pipeline/infrastructure-project/default-value.csv
# Added fields: entry-number, resource, start-date, end-date, entry-date
# Overwritten file: pipeline/infrastructure-project/default-value.csv
# --------------------------------------------------
# Reading file: pipeline/infrastructure-project/combine.csv
# Added fields: resource
# Overwritten file: pipeline/infrastructure-project/combine.csv
# --------------------------------------------------
# Reading file: pipeline/infrastructure-project/column.csv
# Added fields: start-date, end-date, entry-date
# Overwritten file: pipeline/infrastructure-project/column.csv
# --------------------------------------------------
# Reading file: pipeline/infrastructure-project/convert.csv
# Added fields: plugin, start-date, end-date, entry-date, endpoint, parameters
# Overwritten file: pipeline/infrastructure-project/convert.csv
# --------------------------------------------------
# Reading file: pipeline/infrastructure-project/default.csv
# Added fields: entry-number, endpoint
# Overwritten file: pipeline/infrastructure-project/default.csv
# --------------------------------------------------
# Reading file: pipeline/infrastructure-project/patch.csv
# Added fields: entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/infrastructure-project/patch.csv
# --------------------------------------------------
# Reading file: pipeline/infrastructure-project/concat.csv
# Added fields: endpoint
# Overwritten file: pipeline/infrastructure-project/concat.csv
# --------------------------------------------------
# Reading file: pipeline/infrastructure-project/skip.csv
# Added fields: entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/infrastructure-project/skip.csv
# --------------------------------------------------
# Reading file: pipeline/infrastructure-project/lookup.csv
# Added fields: value, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/infrastructure-project/lookup.csv
# --------------------------------------------------
# Reading file: pipeline/infrastructure-project/old-entity.csv
# Added fields: end-date, entry-date, start-date
# Overwritten file: pipeline/infrastructure-project/old-entity.csv
# --------------------------------------------------
# Reading file: pipeline/ancient-woodland/combine.csv
# Added fields: resource
# Overwritten file: pipeline/ancient-woodland/combine.csv
# --------------------------------------------------
# Reading file: pipeline/ancient-woodland/column.csv
# Added fields: start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/ancient-woodland/column.csv
# --------------------------------------------------
# Reading file: pipeline/ancient-woodland/convert.csv
# Added fields: dataset, plugin, start-date, end-date, entry-date, endpoint, parameters
# Overwritten file: pipeline/ancient-woodland/convert.csv
# --------------------------------------------------
# Reading file: pipeline/ancient-woodland/default.csv
# Added fields: entry-number, endpoint
# Overwritten file: pipeline/ancient-woodland/default.csv
# --------------------------------------------------
# Reading file: pipeline/ancient-woodland/patch.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/ancient-woodland/patch.csv
# --------------------------------------------------
# Reading file: pipeline/ancient-woodland/concat.csv
# Added fields: dataset, endpoint
# Overwritten file: pipeline/ancient-woodland/concat.csv
# --------------------------------------------------
# Reading file: pipeline/ancient-woodland/transform.csv
# Added fields: dataset, entry-number, resource, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/ancient-woodland/transform.csv
# --------------------------------------------------
# Reading file: pipeline/ancient-woodland/skip.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/ancient-woodland/skip.csv
# --------------------------------------------------
# Reading file: pipeline/ancient-woodland/lookup.csv
# Added fields: value, entry-number, resource, start-date, organisation, end-date, entry-date, endpoint
# Overwritten file: pipeline/ancient-woodland/lookup.csv
# --------------------------------------------------
# Reading file: pipeline/ancient-woodland/old-entity.csv
# Added fields: end-date, entry-date, start-date
# Overwritten file: pipeline/ancient-woodland/old-entity.csv
# --------------------------------------------------
# Reading file: pipeline/planning-permission-type/column.csv
# Added fields: start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/planning-permission-type/column.csv
# --------------------------------------------------
# Reading file: pipeline/planning-permission-type/convert.csv
# Added fields: dataset, plugin, start-date, end-date, entry-date, endpoint, parameters
# Overwritten file: pipeline/planning-permission-type/convert.csv
# --------------------------------------------------
# Reading file: pipeline/planning-permission-type/default.csv
# Added fields: entry-number, endpoint
# Overwritten file: pipeline/planning-permission-type/default.csv
# --------------------------------------------------
# Reading file: pipeline/planning-permission-type/patch.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/planning-permission-type/patch.csv
# --------------------------------------------------
# Reading file: pipeline/planning-permission-type/concat.csv
# Added fields: dataset, endpoint
# Overwritten file: pipeline/planning-permission-type/concat.csv
# --------------------------------------------------
# Reading file: pipeline/planning-permission-type/transform.csv
# Added fields: dataset, entry-number, resource, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/planning-permission-type/transform.csv
# --------------------------------------------------
# Reading file: pipeline/planning-permission-type/skip.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/planning-permission-type/skip.csv
# --------------------------------------------------
# Reading file: pipeline/planning-permission-type/lookup.csv
# Added fields: value, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/planning-permission-type/lookup.csv
# --------------------------------------------------
# Reading file: pipeline/planning-permission-type/old-entity.csv
# Added fields: end-date, entry-date, start-date
# Overwritten file: pipeline/planning-permission-type/old-entity.csv
# --------------------------------------------------
# Reading file: pipeline/infrastructure-funding-statement/column.csv
# Added fields: dataset, column, start-date, field, end-date, entry-date, endpoint
# Overwritten file: pipeline/infrastructure-funding-statement/column.csv
# ...
# --------------------------------------------------
# Reading file: pipeline/local-planning-authority/transform.csv
# Added fields: entry-number, resource, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/local-planning-authority/transform.csv
# --------------------------------------------------
# Reading file: pipeline/local-planning-authority/skip.csv
# Added fields: entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/local-planning-authority/skip.csv
# --------------------------------------------------
# Reading file: pipeline/local-planning-authority/lookup.csv
# Added fields: reference, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/local-planning-authority/lookup.csv
# --------------------------------------------------
# Reading file: pipeline/local-planning-authority/old-entity.csv
# Added fields: end-date, entry-date, start-date
# Overwritten file: pipeline/local-planning-authority/old-entity.csv
# --------------------------------------------------
# Reading file: pipeline/brownfield-land/column.csv
# Added fields: start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/brownfield-land/column.csv
# --------------------------------------------------
# Reading file: pipeline/brownfield-land/convert.csv
# Added fields: plugin, start-date, end-date, entry-date, endpoint, parameters
# Overwritten file: pipeline/brownfield-land/convert.csv
# --------------------------------------------------
# Reading file: pipeline/brownfield-land/default.csv
# Added fields: entry-number, endpoint
# Overwritten file: pipeline/brownfield-land/default.csv
# --------------------------------------------------
# Reading file: pipeline/brownfield-land/patch.csv
# Added fields: entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/brownfield-land/patch.csv
# --------------------------------------------------
# Reading file: pipeline/brownfield-land/filter.csv
# Added fields: entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/brownfield-land/filter.csv
# --------------------------------------------------
# Reading file: pipeline/brownfield-land/concat.csv
# Added fields: endpoint
# Overwritten file: pipeline/brownfield-land/concat.csv
# --------------------------------------------------
# Reading file: pipeline/brownfield-land/transform.csv
# Added fields: entry-number, resource, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/brownfield-land/transform.csv
# --------------------------------------------------
# Reading file: pipeline/brownfield-land/skip.csv
# Added fields: entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/brownfield-land/skip.csv
# --------------------------------------------------
# Reading file: pipeline/brownfield-land/lookup.csv
# Added fields: value, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/brownfield-land/lookup.csv
# --------------------------------------------------
# Reading file: pipeline/brownfield-land/old-entity.csv
# Added fields: end-date, entry-date, start-date
# Overwritten file: pipeline/brownfield-land/old-entity.csv
# --------------------------------------------------
# Reading file: pipeline/conservation-area/combine.csv
# Added fields: resource
# Overwritten file: pipeline/conservation-area/combine.csv
# --------------------------------------------------
# Reading file: pipeline/conservation-area/column.csv
# Added fields: start-date, end-date, entry-date
# Overwritten file: pipeline/conservation-area/column.csv
# --------------------------------------------------
# Reading file: pipeline/conservation-area/convert.csv
# Added fields: dataset, plugin, start-date, end-date, entry-date, endpoint, parameters
# Overwritten file: pipeline/conservation-area/convert.csv
# --------------------------------------------------
# Reading file: pipeline/conservation-area/default.csv
# Added fields: entry-number, endpoint
# Overwritten file: pipeline/conservation-area/default.csv
# --------------------------------------------------
# Reading file: pipeline/conservation-area/patch.csv
# Added fields: entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/conservation-area/patch.csv
# --------------------------------------------------
# Reading file: pipeline/conservation-area/concat.csv
# Added fields: endpoint
# Overwritten file: pipeline/conservation-area/concat.csv
# --------------------------------------------------
# Reading file: pipeline/conservation-area/skip.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/conservation-area/skip.csv
# --------------------------------------------------
# Reading file: pipeline/conservation-area/lookup.csv
# Added fields: value, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/conservation-area/lookup.csv
# --------------------------------------------------
# Reading file: pipeline/conservation-area/old-entity.csv
# Added fields: end-date, notes, entry-date, start-date
# Overwritten file: pipeline/conservation-area/old-entity.csv
# --------------------------------------------------
# Reading file: pipeline/planning-permission-status/column.csv
# Added fields: start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/planning-permission-status/column.csv
# --------------------------------------------------
# Reading file: pipeline/planning-permission-status/convert.csv
# Added fields: dataset, plugin, start-date, end-date, entry-date, endpoint, parameters
# Overwritten file: pipeline/planning-permission-status/convert.csv
# --------------------------------------------------
# Reading file: pipeline/planning-permission-status/default.csv
# Added fields: entry-number, endpoint
# Overwritten file: pipeline/planning-permission-status/default.csv
# --------------------------------------------------
# Reading file: pipeline/planning-permission-status/patch.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/planning-permission-status/patch.csv
# --------------------------------------------------
# Reading file: pipeline/planning-permission-status/concat.csv
# Added fields: dataset, endpoint
# Overwritten file: pipeline/planning-permission-status/concat.csv
# --------------------------------------------------
# Reading file: pipeline/planning-permission-status/transform.csv
# Added fields: dataset, entry-number, resource, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/planning-permission-status/transform.csv
# --------------------------------------------------
# Reading file: pipeline/planning-permission-status/skip.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/planning-permission-status/skip.csv
# --------------------------------------------------
# Reading file: pipeline/planning-permission-status/lookup.csv
# Added fields: value, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/planning-permission-status/lookup.csv
# --------------------------------------------------
# Reading file: pipeline/planning-permission-status/old-entity.csv
# Added fields: end-date, entry-date, start-date
# Overwritten file: pipeline/planning-permission-status/old-entity.csv
# --------------------------------------------------
# Reading file: pipeline/developer-contributions/column.csv
# Added fields: start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/developer-contributions/column.csv
# --------------------------------------------------
# Reading file: pipeline/developer-contributions/convert.csv
# Added fields: dataset, plugin, start-date, end-date, entry-date, endpoint, parameters
# Overwritten file: pipeline/developer-contributions/convert.csv
# --------------------------------------------------
# Reading file: pipeline/developer-contributions/default.csv
# Added fields: entry-number, endpoint
# Overwritten file: pipeline/developer-contributions/default.csv
# --------------------------------------------------
# Reading file: pipeline/developer-contributions/patch.csv
# Added fields: entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/developer-contributions/patch.csv
# --------------------------------------------------
# Reading file: pipeline/developer-contributions/concat.csv
# Added fields: dataset, endpoint
# Overwritten file: pipeline/developer-contributions/concat.csv
# --------------------------------------------------
# Reading file: pipeline/developer-contributions/transform.csv
# Added fields: dataset, entry-number, resource, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/developer-contributions/transform.csv
# --------------------------------------------------
# Reading file: pipeline/developer-contributions/skip.csv
# Added fields: entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/developer-contributions/skip.csv
# --------------------------------------------------
# Reading file: pipeline/developer-contributions/lookup.csv
# Added fields: value, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/developer-contributions/lookup.csv
# --------------------------------------------------
# Reading file: pipeline/developer-contributions/old-entity.csv
# Added fields: end-date, entry-date, start-date
# Overwritten file: pipeline/developer-contributions/old-entity.csv
# --------------------------------------------------
# Reading file: pipeline/national-park/column.csv
# Added fields: start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/national-park/column.csv
# --------------------------------------------------
# Reading file: pipeline/national-park/convert.csv
# Added fields: dataset, plugin, start-date, end-date, entry-date, endpoint, parameters
# Overwritten file: pipeline/national-park/convert.csv
# --------------------------------------------------
# Reading file: pipeline/national-park/default.csv
# Added fields: entry-number, endpoint
# Overwritten file: pipeline/national-park/default.csv
# --------------------------------------------------
# Reading file: pipeline/national-park/patch.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/national-park/patch.csv
# --------------------------------------------------
# Reading file: pipeline/national-park/filter.csv
# Added fields: entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/national-park/filter.csv
# --------------------------------------------------
# Reading file: pipeline/national-park/concat.csv
# Added fields: dataset, endpoint
# Overwritten file: pipeline/national-park/concat.csv
# --------------------------------------------------
# Reading file: pipeline/national-park/transform.csv
# Added fields: dataset, entry-number, resource, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/national-park/transform.csv
# --------------------------------------------------
# Reading file: pipeline/national-park/skip.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/national-park/skip.csv
# --------------------------------------------------
# Reading file: pipeline/national-park/lookup.csv
# Added fields: value, entry-number, resource, start-date, organisation, end-date, entry-date, endpoint
# Overwritten file: pipeline/national-park/lookup.csv
# --------------------------------------------------
# Reading file: pipeline/national-park/old-entity.csv
# Added fields: end-date, entry-date, start-date
# Overwritten file: pipeline/national-park/old-entity.csv
# --------------------------------------------------
# Reading file: pipeline/site-category/column.csv
# Added fields: start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/site-category/column.csv
# --------------------------------------------------
# Reading file: pipeline/site-category/convert.csv
# Added fields: dataset, plugin, start-date, end-date, entry-date, endpoint, parameters
# Overwritten file: pipeline/site-category/convert.csv
# --------------------------------------------------
# Reading file: pipeline/site-category/default.csv
# Added fields: entry-number, endpoint
# Overwritten file: pipeline/site-category/default.csv
# --------------------------------------------------
# Reading file: pipeline/site-category/patch.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/site-category/patch.csv
# --------------------------------------------------
# Reading file: pipeline/site-category/concat.csv
# Added fields: dataset, endpoint
# Overwritten file: pipeline/site-category/concat.csv
# --------------------------------------------------
# Reading file: pipeline/site-category/transform.csv
# Added fields: dataset, entry-number, resource, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/site-category/transform.csv
# --------------------------------------------------
# Reading file: pipeline/site-category/skip.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/site-category/skip.csv
# --------------------------------------------------
# Reading file: pipeline/site-category/lookup.csv
# Added fields: value, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/site-category/lookup.csv
# --------------------------------------------------
# Reading file: pipeline/site-category/old-entity.csv
# Added fields: end-date, entry-date, start-date
# Overwritten file: pipeline/site-category/old-entity.csv
# --------------------------------------------------
# Reading file: pipeline/central-activities-zone/column.csv
# Added fields: start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/central-activities-zone/column.csv
# --------------------------------------------------
# Reading file: pipeline/central-activities-zone/convert.csv
# Added fields: dataset, plugin, start-date, end-date, entry-date, endpoint, parameters
# Overwritten file: pipeline/central-activities-zone/convert.csv
# --------------------------------------------------
# Reading file: pipeline/central-activities-zone/default.csv
# Added fields: entry-number, endpoint
# Overwritten file: pipeline/central-activities-zone/default.csv
# --------------------------------------------------
# Reading file: pipeline/central-activities-zone/patch.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/central-activities-zone/patch.csv
# --------------------------------------------------
# Reading file: pipeline/central-activities-zone/filter.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/central-activities-zone/filter.csv
# --------------------------------------------------
# Reading file: pipeline/central-activities-zone/concat.csv
# Added fields: dataset, endpoint
# Overwritten file: pipeline/central-activities-zone/concat.csv
# --------------------------------------------------
# Reading file: pipeline/central-activities-zone/transform.csv
# Added fields: dataset, entry-number, resource, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/central-activities-zone/transform.csv
# --------------------------------------------------
# Reading file: pipeline/central-activities-zone/skip.csv
# Added fields: dataset, entry-number, start-date, end-date, entry-date, endpoint
# Overwritten file: pipeline/central-activities-zone/skip.csv
# --------------------------------------------------
# Reading file: pipeline/central-activities-zone/lookup.csv
# Added fields: value, start-date, organisation, end-date, entry-date, endpoint
# Overwritten file: pipeline/central-activities-zone/lookup.csv
# --------------------------------------------------
# Reading file: pipeline/central-activities-zone/old-entity.csv
# Added fields: end-date, entry-date, start-date
# Overwritten file: pipeline/central-activities-zone/old-entity.csv
# --------------------------------------------------

# %%
# # generate table of all collections, files and fields for cross-comparison

# results = dict({"collection" : [],
#                 "file" : [],
#                 "field" : []})

# for path,subdir,files in os.walk("./pipeline"):
#    for file in files:    
       
#        collection_name = path.split("/")[-1]
#        file_name = file.split(".")[0]

#        if file.lower().endswith('.csv'):
#           try:
#             #  print(os.path.join(path, file))
#              df = pd.read_csv(os.path.join(path, file))
#              fields = df.columns.values

#              for field_name in fields:

#                 results["collection"].append(collection_name)
#                 results["file"].append(file_name)
#                 results["field"].append(field_name)
             

#           except pd.errors.EmptyDataError:
#              print(f"Empty CSV file: {file}")
#           except pd.errors.ParserError:
#              print(f"Error reading CSV file: {file}")

# pd.DataFrame.from_dict(results).groupby(["file", "field"]).size().reset_index(name = "count").to_csv("temp_file_field_check.csv", index=False)
